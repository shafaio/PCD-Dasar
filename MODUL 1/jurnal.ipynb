# %% [markdown]
# NO 1 HISTOGRAM

# %%
# melakukan import library
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# melakukan import real.jpg dalam variabel img dengan library matplotlib
img = plt.imread('img/real.jpg')

# %%
print(img.shape) # menampilkan sebuah dimensi dari img dengan nilai 1280, 1023, 3
x, y, z = img.shape # menginisialisasi kan x untuk tinggi, y untuk lebar, dan z untuk RGB
# Out:
# (1280, 1023, 3)

# %%
plt.imshow(img) #menampilkan citra dari img

# %%
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY) 
# menginisialisasi variabel gray yang didalamnya melakukan konversi RGB ke dalam GRAY
plt.imshow(gray, cmap='gray')
# menampilkan hasil gambar dari konversi gambar yang berada pada variabel gray

# %%
print(gray.max()) # menampilkan nilai maksimal dari gambar yang sudah di konversikan ke dalam grayscale 
print(gray.min()) # menampilkan nilai minimal dari gambar yang sudah di konversikan ke dalam grayscale
print(img) # menampilkan matriks citra dari gambar RGB
# Out:
# 255
# 0
# [[[ 16  19  36]
#   [ 16  19  36]
#   [ 16  19  36]
#   ...
#   [ 13  16  23]
#   [ 13  16  23]
#   [ 13  16  23]]
#
#  [[ 16  19  36]
#   [ 16  19  36]
#   [ 16  19  36]
#   ...
#   [ 13  16  23]
#   [ 13  16  23]
#   [ 13  16  23]]
#
#  [[ 16  19  36]
#   [ 16  19  36]
#   [ 16  19  34]
#   ...
#   [ 13  16  23]
#   [ 13  16  23]
#   [ 13  16  23]]
#
#  ...
#
#  [[ 97 128   8]
#   [ 98 129   9]
#   [100 131  11]
#   ...
#   [109 144  16]
#   [111 146  18]
#   [112 147  19]]
#
#  [[ 99 131   8]
#   [100 132   9]
#   [102 134  11]
#   ...
#   [116 151  21]
#   [115 150  20]
#   [113 148  20]]
#
#  [[100 132   9]
#   [103 135  12]
#   [105 137  14]
#   ...
#   [121 156  26]
#   [117 152  22]
#   [113 148  20]]]

# %%
sumGray = np.zeros(256).astype(int) 
# menginisialisasi variabel sumGray yang memanggil library numpy dengan function zeros yang bertipe data integer

# %%
for i in range(x): # perulangan baris dalam varibel i dengan batasan nilai dari variabel x
    for j in range(y): # perulangan kolol dalam varibel j dengan batasan nilai dari variabel y
        val = gray[i, j] # menginisialisasi variabel val yang akan berisi dengan nilai pixel sesuai dengan perulangan
        sumGray [val] +=1 # memberi nilai pada setiap elemen pixel yang melalui perulangan

# %%
grayValue = [i for i in range (256)]

# %%
plt.bar(grayValue, sumGray)
# menampilkan grafik bar histogram dengan bantuan memanggil library plt dan sumbu x nilai dari data grayValue sedangkan sumbu y data sumGray
# Out:
# <BarContainer object of 256 artists>

# %%
plt.bar(grayValue, sumGray/(x*y))
plt.xlabel("Histogram Keabuan")
plt.ylabel("Probabilitas")
plt.savefig("record.png")
# plt.bar_label("H")

# %%
ni = sumGray
print(ni)
# plt.imshow(sumGray)
# Out:
# [   53   179   312   368   330   327   354   355   521   630   796   881
#   1132  1185  1271  1204  1224  1188  1103   906   942   894  1030   948
#    882   887   976  1022  1022  1029  1092  1111  1180  1309  1499  1879
#   3005  7691 10715 14885 14057 14251 18251 18580 18102 16512 17270 13194
#  12162 12330  9883  8912  8104  7261  6410  7385  6322  4796  4548  4553
#   4304  4875  4585  4719  4751  4310  4254  4109  4455  3558  3767  3711
#   3491  3583  3354  3552  3649  3573  4121  4499  4012  3619  3711  3503
#   3717  3868  4217  4683  4899  4846  5264  5379  5302  5457  5801  5958
#   6072  6833  7674  8437  9485 11786 14051 15970 17548 19445 19988 20175
#  18685 17746 17469 18222 18161 18954 18402 17901 18582 20172 20818 19124
#  18090 16145 13633 12485 11926 11537 11432 10579 10798 10396  9342  8439
#   7498  6281  5640  4759  4206  3706  3549  3431  3343  3320  3414  3312
#   3253  3117  3119  3082  3308  3013  3117  2715  2835  2469  2543  2545
#   2544  2374  2473  2421  2423  2387  2358  2524  2639  3645  3893  4164
#   7232  7516  8262  8594 10710  7145  5306  3770  4157  4428  4536  3621
#   2767  1889  1226  1186  1203  1279  1171  1139  1211  1168  1266  1256
#   1266  1336  1348  1291  1217  1318  1334  1385  1292  1271  1230  1209
#   1241  1094  1092  1028  1051  1123  1194  1225  1259  1202  1243  1200
#   1265  1208  1184  1110  1176  1257  1245  1363  1538  1646  1492  1438
#   1495  1612  1718  1939  2024  2203  2135  2328  2409  2637  3262  3187
#   2966  2719  2779  2982  2880  3059  3056  3079  3269  3485  3523  3415
#   3501  3532  3816  2443]

# %%
hi = ni / x*y # menginisialisai variabel hi yang berisi nilai dari hasil perhitungan derajat keabuan citra
print(hi) # menampilkan matriks dari variabel hi
# Out:
# [   42.35859375   143.06015625   249.35625      294.1125
#    263.7421875    261.34453125   282.9234375    283.72265625
#    416.39296875   503.5078125    636.178125     704.11171875
#    904.715625     947.07421875  1015.80703125   962.259375
#    978.24375      949.471875     881.53828125   724.0921875
#    752.8640625    714.5015625    823.1953125    757.659375
#    704.9109375    708.90703125   780.0375       816.8015625
#    816.8015625    822.39609375   872.746875     887.93203125
#    943.078125    1046.17734375  1198.02890625  1501.73203125
#   2401.65234375  6146.79140625  8563.62890625 11896.37109375
#  11234.61796875 11389.66640625 14586.54140625 14849.484375
#  14467.4578125  13196.7        13802.5078125  10544.8921875
#   9720.0984375   9854.3671875   7898.67890625  7122.6375
#   6476.86875     5803.12734375  5122.9921875   5902.23046875
#   5052.6609375   3833.053125    3634.846875    3638.84296875
#   3439.8375      3896.19140625  3664.41796875  3771.51328125
#   3797.08828125  3444.6328125   3399.8765625   3283.98984375
#   3560.51953125  2843.6203125   3010.65703125  2965.90078125
#   2790.07265625  2863.60078125  2680.5796875   2838.825
#   2916.34921875  2855.60859375  3293.58046875  3595.68515625
#   3206.465625    2892.37265625  2965.90078125  2799.66328125
#   2970.69609375  3091.378125    3370.30546875  3742.74140625
#   3915.37265625  3873.0140625   4207.0875      4298.99765625
#   4237.4578125   4361.33671875  4636.26796875  4761.7453125
#   4852.85625     5461.06171875  6133.2046875   6743.00859375
#   7580.58984375  9419.5921875  11229.82265625 12763.5234375
#  14024.690625   15540.80859375 15974.784375   16124.23828125
#  14933.40234375 14182.9359375  13961.55234375 14563.3640625
#  14514.61171875 15148.3921875  14707.2234375  14306.81484375
#  14851.0828125  16121.840625   16638.1359375  15284.259375
#  14457.8671875  12903.38671875 10895.74921875  9978.24609375
#   9531.4828125   9220.58671875  9136.66875     8454.93515625
#   8629.9640625   8308.678125    7466.3015625   6744.60703125
#   5992.5421875   5019.89296875  4507.59375     3803.48203125
#   3361.5140625   2961.9046875   2836.42734375  2742.11953125
#   2671.78828125  2653.40625     2728.5328125   2647.0125
#   2599.85859375  2491.16484375  2492.76328125  2463.1921875
#   2643.815625    2408.04609375  2491.16484375  2169.87890625
#   2265.78515625  1973.27109375  2032.41328125  2034.01171875
#   2033.2125      1897.3453125   1976.46796875  1934.90859375
#   1936.50703125  1907.73515625  1884.5578125   2017.228125
#   2109.13828125  2913.15234375  3111.35859375  3327.946875
#   5779.95        6006.928125    6603.1453125   6868.4859375
#   8559.6328125   5710.41796875  4240.6546875   3013.0546875
#   3322.35234375  3538.940625    3625.25625     2893.97109375
#   2211.43828125  1509.72421875   979.8421875    947.8734375
#    961.46015625  1022.20078125   935.88515625   910.31015625
#    967.85390625   933.4875      1011.8109375   1003.81875
#   1011.8109375   1067.75625     1077.346875    1031.79140625
#    972.64921875  1053.3703125   1066.1578125   1106.91796875
#   1032.590625    1015.80703125   983.0390625    966.25546875
#    991.83046875   874.3453125    872.746875     821.596875
#    839.97890625   897.52265625   954.2671875    979.04296875
#   1006.21640625   960.6609375    993.42890625   959.0625
#   1011.01171875   965.45625      946.275        887.1328125
#    939.88125     1004.61796875   995.02734375  1089.33515625
#   1229.1984375   1315.5140625   1192.434375    1149.2765625
#   1194.83203125  1288.340625    1373.0578125   1549.68515625
#   1617.61875     1760.67890625  1706.33203125  1860.58125
#   1925.31796875  2107.53984375  2607.0515625   2547.11015625
#   2370.4828125   2173.07578125  2221.02890625  2383.2703125
#   2301.75        2444.81015625  2442.4125      2460.79453125
#   2612.64609375  2785.27734375  2815.64765625  2729.33203125
#   2798.06484375  2822.840625    3049.81875     1952.49140625]

# %% [markdown]
# NO 2 KONVOLUSI

# %%
gbr = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
# menginisialisasi variabel gray yang didalamnya melakukan konversi RGB ke dalam GRAY
plt.imshow(gray, cmap='gray')
# menampilkan citra yang berada pada variabel gbr dengan bantuan library plt dan dengan nilai colormap 'gray/abu-abu'

# %%
kernel = np.array([ #merupakan nilai kernel yang di input dalam bentuk array
    [0, -1, 0],
    [-1, 5, -1],
    [0, -1, 0],
    [-1, 5, -1]
])

# %%
gbr.shape
# Out:
# (1280, 1023)

# %%
konv = np.zeros(gbr.shape) #merupakan script untuk menggunakan padding 0
konvclip = np.zeros(gbr.shape) #merupakan script untuk menggunakan padding 0
konv.shape
for i in range(1278): # perulangan pada barisnya hingga pada baris ke 1278
    for j in range(1021): # perulangan pada kolomnya hingga kolom ke 1021
        konv[i][j]=gray[i][j]*kernel[0][0]+gray[i][j+1]*kernel[0][1]+gray[i][j+2]*kernel[0][2]+gray[i+1][j]*kernel[1][0]+gray[i+1][j+1]*kernel[1][1]+gray[i+1][j+2]*kernel[1][2]+gray[i+2][j]*kernel[2][0]+gray[i+2][j+1]*kernel[2][1]+gray[i+2][j+2]*kernel[2,2]
        konvclip [i][j] = konv[i][j]

        if konvclip[i][j] < 0:
            konvclip [i][j] = 0
        elif konvclip[i][j] > 255:
            konvclip[i][j] = 255

# %%
fig = plt.figure()
fig.add_subplot(121)
plt.imshow(konv, cmap='gray') 
plt.xlabel("Tanpa Clipping")
fig.add_subplot(122)
plt.imshow(konvclip, cmap='gray')
plt.xlabel("Clipping")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
